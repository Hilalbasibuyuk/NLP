# %%
from transformers import pipeline
# Out:
# ---------------------------------------------------------------------------
# SymbolAlreadyExposedError                 Traceback (most recent call last)
# File ~\anaconda3\envs\pytorch\lib\site-packages\transformers\utils\import_utils.py:1586, in _LazyModule._get_module(self, module_name)
#    1585 try:
# -> 1586     return importlib.import_module("." + module_name, self.__name__)
#    1587 except Exception as e:
#
# File ~\anaconda3\envs\pytorch\lib\importlib\__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1014, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:991, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:975, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:671, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:843, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:219, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\transformers\pipelines\__init__.py:26
#      25 from ..feature_extraction_utils import PreTrainedFeatureExtractor
# ---> 26 from ..image_processing_utils import BaseImageProcessor
#      27 from ..models.auto.configuration_auto import AutoConfig
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\transformers\image_processing_utils.py:21
#      20 from .image_processing_base import BatchFeature, ImageProcessingMixin
# ---> 21 from .image_transforms import center_crop, normalize, rescale
#      22 from .image_utils import ChannelDimension
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\transformers\image_transforms.py:49
#      48 if is_tf_available():
# ---> 49     import tensorflow as tf
#      51 if is_flax_available():
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\tensorflow\__init__.py:478
#     477 try:
# --> 478   importlib.import_module("keras.optimizers")
#     479 except (ImportError, AttributeError):
#
# File ~\anaconda3\envs\pytorch\lib\importlib\__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\keras\__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras import __internal__
#       4 from keras import activations
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\keras\__internal__\__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras.__internal__ import backend
#       4 from keras.__internal__ import layers
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\keras\__internal__\backend\__init__.py:3
#       1 """AUTOGENERATED. DO NOT EDIT."""
# ----> 3 from keras.src.backend import _initialize_variables as initialize_variables
#       4 from keras.src.backend import track_variable
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\keras\src\__init__.py:21
#      15 """Implementation of the Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
# ---> 21 from keras.src import applications
#      22 from keras.src import distribute
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\keras\src\applications\__init__.py:18
#      15 """Keras Applications are premade architectures with pre-trained weights."""
# ---> 18 from keras.src.applications.convnext import ConvNeXtBase
#      19 from keras.src.applications.convnext import ConvNeXtLarge
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\keras\src\applications\convnext.py:28
#      26 import tensorflow.compat.v2 as tf
# ---> 28 from keras.src import backend
#      29 from keras.src import initializers
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\keras\src\backend.py:35
#      34 from keras.src.dtensor import dtensor_api as dtensor
# ---> 35 from keras.src.engine import keras_tensor
#      36 from keras.src.utils import control_flow_util
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\keras\src\engine\keras_tensor.py:19
#      17 import tensorflow.compat.v2 as tf
# ---> 19 from keras.src.utils import object_identity
#      21 # isort: off
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\keras\src\utils\__init__.py:20
#      17 # isort: off
#      18
#      19 # Serialization related
# ---> 20 from keras.src.saving.serialization_lib import deserialize_keras_object
#      21 from keras.src.saving.serialization_lib import serialize_keras_object
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\keras\src\saving\serialization_lib.py:28
#      27 from keras.src.saving.legacy import serialization as legacy_serialization
# ---> 28 from keras.src.saving.legacy.saved_model.utils import in_tf_saved_model_scope
#      29 from keras.src.utils import generic_utils
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\keras\src\saving\legacy\saved_model\utils.py:30
#      29 from keras.src.utils.generic_utils import LazyLoader
# ---> 30 from keras.src.utils.layer_utils import CallFunctionSpec
#      32 training_lib = LazyLoader("training_lib", globals(), "keras.src.engine.training")
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\keras\src\utils\layer_utils.py:26
#      24 import tensorflow.compat.v2 as tf
# ---> 26 from keras.src import initializers
#      27 from keras.src.utils import io_utils
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\keras\src\initializers\__init__.py:23
#      22 from keras.src.initializers import initializers
# ---> 23 from keras.src.initializers import initializers_v1
#      24 from keras.src.saving import serialization_lib
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\keras\src\initializers\initializers_v1.py:32
#      30 _v1_glorot_normal_initializer = tf.compat.v1.glorot_normal_initializer
# ---> 32 keras_export(v1=["keras.initializers.Zeros", "keras.initializers.zeros"])(
#      33     _v1_zeros_initializer
#      34 )
#      35 keras_export(v1=["keras.initializers.Ones", "keras.initializers.ones"])(
#      36     _v1_ones_initializer
#      37 )
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\tensorflow\python\util\tf_export.py:348, in api_export.__call__(self, func)
#     347 _, undecorated_func = tf_decorator.unwrap(func)
# --> 348 self.set_attr(undecorated_func, api_names_attr, self._names)
#     349 self.set_attr(undecorated_func, api_names_attr_v1, self._names_v1)
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\tensorflow\python\util\tf_export.py:364, in api_export.set_attr(self, func, api_names_attr, names)
#     363   if not self._allow_multiple_exports:
# --> 364     raise SymbolAlreadyExposedError(
#     365         'Symbol %s is already exposed as %s.' %
#     366         (func.__name__, getattr(func, api_names_attr)))  # pylint: disable=protected-access
#     367 setattr(func, api_names_attr, names)
#
# SymbolAlreadyExposedError: Symbol Zeros is already exposed as ().
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from transformers import pipeline
#
# File <frozen importlib._bootstrap>:1039, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\transformers\utils\import_utils.py:1576, in _LazyModule.__getattr__(self, name)
#    1574     value = self._get_module(name)
#    1575 elif name in self._class_to_module.keys():
# -> 1576     module = self._get_module(self._class_to_module[name])
#    1577     value = getattr(module, name)
#    1578 else:
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\transformers\utils\import_utils.py:1588, in _LazyModule._get_module(self, module_name)
#    1586     return importlib.import_module("." + module_name, self.__name__)
#    1587 except Exception as e:
# -> 1588     raise RuntimeError(
#    1589         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1590         f" traceback):\n{e}"
#    1591     ) from e
#
# RuntimeError: Failed to import transformers.pipelines because of the following error (look up to see its traceback):
# Symbol Zeros is already exposed as ().

# %%
pipe = pipeline(task = "ner")

# %%
pipe("Apple Inc. was founded by Steve Jobs, Steve Wozniak, and Ronald Wayne on April 1, 1976, in Cupertino, California.")
